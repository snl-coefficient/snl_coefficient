# %%
import pandas as pd
import altair as alt

potential_snl = pd.read_csv("/Users/estene/Documents/GitHub/snl_coefficient/data/full_data_snl_movies_coefficient.csv")
definitive_snl = potential_snl[potential_snl['movie_coefficient']>=1]

# %%
definitive_snl
# Out:
#                                    imdb_link  movie_coefficient  \
# 4201   https://www.imdb.com/title/tt0330328/           1.006851
# 4202   https://www.imdb.com/title/tt0346462/           1.015434
# 4203   https://www.imdb.com/title/tt2393995/           1.028163
# 4204   https://www.imdb.com/title/tt5005908/           1.038073
# 4205  https://www.imdb.com/title/tt10324166/           1.039947
# ...                                      ...                ...
# 4489   https://www.imdb.com/title/tt1045653/          13.959473
# 4490   https://www.imdb.com/title/tt6548600/          14.637310
# 4491  https://www.imdb.com/title/tt11306452/          14.740002
# 4492   https://www.imdb.com/title/tt0500149/          16.442724
# 4493   https://www.imdb.com/title/tt3677742/          18.486299
#
#                                                   title  \
# 4201                    Gilda Radner's Greatest Moments
# 4202              The 43rd Annual Primetime Emmy Awards
# 4203                             The 2012 Comedy Awards
# 4204  2011 White House Correspondents' Association D...
# 4205   Unbreakable Kimmy Schmidt: Kimmy vs the Reverend
# ...                                                 ...
# 4489  Saturday Night Live: The Best of Commercial Pa...
# 4490            A Saturday Night Live Christmas Special
# 4491            A Saturday Night Live Christmas Special
# 4492                             Saturday Night Live 25
# 4493      Saturday Night Live: 40th Anniversary Special
#
#                                              media_type  credits_count  \
# 4201                  ['TV Special', '20022002', '43m']              7
# 4202                         ['TV Special', '19911991']              9
# 4203                   ['TV Special', '20122012', '2h']              9
# 4204                   ['TV Special', '20112011', '2h']              5
# 4205   ['TV Movie', '20202020', 'TV-14TV-14', '1h 20m']             10
# ...                                                 ...            ...
# 4489               ['TV Special', '20052005', '1h 25m']             56
# 4490     ['TV Special', '20162016', 'TV-14TV-14', '2h']             60
# 4491               ['TV Special', '20192019', '1h 24m']             62
# 4492               ['TV Special', '19991999', '2h 41m']             88
# 4493  ['TV Special', '20152015', 'TV-14TV-14', '1h 4...             95
#
#                                               snl_alums  cast_count  \
# 4201  ['Molly Shannon', 'Gilda Radner', 'Dan Aykroyd...           7
# 4202  ['Kevin Nealon', 'Laurie Metcalf', 'Gilbert Go...           9
# 4203  ['Chris Parnell', 'Kristen Wiig', 'Tracy Morga...           9
# 4204  ['Alex Baze', 'John Mulaney', 'Seth Meyers', '...           4
# 4205  ['Chris Parnell', 'Bowen Yang', 'Robert Carloc...           7
# ...                                                 ...         ...
# 4489  ['Jason Sudeikis', 'Robert Carlock', 'Dennis M...          56
# 4490  ['Beck Bennett', 'Akiva Schaffer', 'Jason Sude...          59
# 4491  ['Beck Bennett', 'Sasheer Zamata', 'Akiva Scha...          61
# 4492  ['Anne Beatts', 'David Koechner', 'Nora Dunn',...          79
# 4493  ['Bob Odenkirk', 'Tom Schiller', 'Pete Schultz...          87
#
#                                   genres  \
# 4201                          ['Comedy']
# 4202                                  []
# 4203                          ['Comedy']
# 4204                            ['News']
# 4205  ['Adventure', 'Comedy', 'Mystery']
# ...                                  ...
# 4489                          ['Comedy']
# 4490                          ['Comedy']
# 4491                          ['Comedy']
# 4492  ['Documentary', 'Comedy', 'Music']
# 4493                          ['Comedy']
#
#                                                   stars  num_episodes  \
# 4201  ['Gilda Radner', 'Molly Shannon', 'Victor Garb...             0
# 4202  ['Debbie Allen', 'Kirstie Alley', 'Loni Anders...             0
# 4203  ['Will Arnett', 'Louis C.K.', 'Jim Carrey', 'J...             0
# 4204  ['Seth Meyers', 'Barack Obama', 'Michelle Obam...             0
# 4205  ['Ellie Kemper', 'Tituss Burgess', 'Carol Kane...             0
# ...                                                 ...           ...
# 4489  ['Will Ferrell', 'Ben Affleck', 'Fred Armisen'...             0
# 4490  ['Darlene Love', 'Amy Adams', 'Fred Armisen', ...             0
# 4491  ['Darlene Love', 'Amy Adams', 'Casey Affleck',...             0
# 4492  ['Dan Aykroyd', 'Alec Baldwin', 'Candice Berge...             0
# 4493  ['Fred Armisen', 'Dan Aykroyd', 'Alec Baldwin'...             0
#
#                                        principal_people  \
# 4201  ['Dennis Rosenblatt', 'David Leaf', 'Gilda Rad...
# 4202  ['Walter C. Miller', 'Bruce Eric Kaplan', 'Her...
# 4203  ['Beth McCarthy-Miller', 'Chris Albers', 'Lewi...
# 4204  ['Doug Abeles', 'Alex Baze', 'Neal Brennan', '...
# 4205  ['Claire Scanlon', 'Tina Fey', 'Robert Carlock...
# ...                                                 ...
# 4489  ['James Signorelli', 'Robert Carlock', 'Dennis...
# 4490  ['Don Roy King', 'Matt and Oz', 'Beth McCarthy...
# 4491  ['Paul Briganti', 'Don Roy King', 'Matt and Oz...
# 4492  ['Beth McCarthy-Miller', 'James Signorelli', '...
# 4493  ['Don Roy King', 'James Anderson', 'Fred Armis...
#
#                                    production_companies          medium  \
# 4201                                                NaN  ['TV Special']
# 4202                                                NaN  ['TV Special']
# 4203                                                NaN  ['TV Special']
# 4204                                                NaN  ['TV Special']
# 4205  ['3 Arts Entertainment', 'Bevel Gears', 'Littl...    ['TV Movie']
# ...                                                 ...             ...
# 4489                                                NaN  ['TV Special']
# 4490              ['Broadway Video', 'SNL Studios', '']  ['TV Special']
# 4491                                                NaN  ['TV Special']
# 4492  ['Broadway Video', 'National Broadcasting Comp...  ['TV Special']
# 4493              ['Broadway Video', 'SNL Studios', '']  ['TV Special']
#
#       year_start  year_end
# 4201      2002.0    2002.0
# 4202      1991.0    1991.0
# 4203      2012.0    2012.0
# 4204      2011.0    2011.0
# 4205      2020.0    2020.0
# ...          ...       ...
# 4489      2005.0    2005.0
# 4490      2016.0    2016.0
# 4491      2019.0    2019.0
# 4492      1999.0    1999.0
# 4493      2015.0    2015.0
#
# [293 rows x 15 columns]

# %%
##include snl_feature_films.html

# %%
##[EMILY -- Insert a graph that shows Lorne Michaels film projects from 1970 to present that have coefficients over 1] 
# filter by 'film'
lm_film = definitive_snl[definitive_snl['medium'].str.contains('Film')]
lm_film = lm_film[lm_film['snl_alums'].str.contains("Lorne Michaels")]
lm_film = lm_film[lm_film['year_start']>=1969]

lm_film_chart = alt.Chart(lm_film).mark_circle(size=60).encode(
  # Year on the X axis
    x=alt.X('year_start:Q', axis=alt.Axis(format='c', title='Year (Start)'),scale=alt.Scale(domain=(1990, 2022))),
    
    # Number of objects on the Y axis
    y=alt.Y('movie_coefficient:Q', title='SNL Coefficient'),
    
    # Color according to the type
    color = alt.condition(alt.datum.movie_coefficient < 1, alt.value('red'), alt.value('blue')),
    
    # Details on hover
    tooltip=[alt.Tooltip('title:N', title='Title'), 
             alt.Tooltip('year_start:Q', title='Year (Start)'),
             alt.Tooltip('genres:N', title='Genre'),
             alt.Tooltip('medium:N', title='Medium'),
             alt.Tooltip('cast_count:Q', title='Cast Count'),
             alt.Tooltip('movie_coefficient:Q', title='Coefficient')]
).interactive()

lm_film_chart

lm_film_chart.save('visualizations/lorne_michaels_films.html')

# %%
lm_film_chart
# Out:
# alt.Chart(...)

# %%
##[EMILY -- insert a graph that shows Michaels television series from 1970 to present that have coefficients over 1].
# filter by 'film'
# filter by lorne michaels
# filter for coefficient >=1
# filter for start year greater than 1969
lm_tv = definitive_snl[definitive_snl['medium'].str.contains('TV Series')]
lm_tv = lm_tv[lm_tv['snl_alums'].str.contains("Lorne Michaels")]
lm_tv = lm_tv[lm_tv['year_start']>=1969]
lm_tv.shape
# Out:
# (28, 15)

# %%
lm_tv_chart = alt.Chart(lm_tv).mark_circle(size=60).encode(
  # Year on the X axis
    x=alt.X('year_start:Q', axis=alt.Axis(format='c', title='Year (Start)'),scale=alt.Scale(domain=(1990, 2022))),
    
    # Number of objects on the Y axis
    y=alt.Y('movie_coefficient:Q', title='SNL Coefficient'),
    
    # Color according to the type
    color = alt.condition(alt.datum.movie_coefficient < 1, alt.value('red'), alt.value('blue')),
    
    # Details on hover
    tooltip=[alt.Tooltip('title:N', title='Title'), 
             alt.Tooltip('year_start:Q', title='Year (Start)'),
             alt.Tooltip('genres:N', title='Genre'),
             alt.Tooltip('medium:N', title='Medium'),
             alt.Tooltip('cast_count:Q', title='Cast Count'),
             alt.Tooltip('movie_coefficient:Q', title='Coefficient')]
).interactive()

lm_tv_chart

lm_tv_chart.save('visualizations/lorne_michaels_tv.html')

# %%
any_film = definitive_snl[definitive_snl['medium'].str.contains('Film')]

all_films_chart = alt.Chart(any_film).mark_circle(size=60).encode(
  # Year on the X axis
    x=alt.X('year_start:Q', axis=alt.Axis(format='c', title='Year (Start)'),scale=alt.Scale(domain=(1990, 2022))),
    
    # Number of objects on the Y axis
    y=alt.Y('movie_coefficient:Q', title='SNL Coefficient'),
    
    # Color according to the type
    color = alt.condition(alt.datum.movie_coefficient < 1, alt.value('red'), alt.value('blue')),
    
    # Details on hover
    tooltip=[alt.Tooltip('title:N', title='Title'), 
             alt.Tooltip('year_start:Q', title='Year (Start)'),
             alt.Tooltip('genres:N', title='Genre'),
             alt.Tooltip('medium:N', title='Medium'),
             alt.Tooltip('cast_count:Q', title='Cast Count'),
             alt.Tooltip('movie_coefficient:Q', title='Coefficient')]
).interactive()

all_films_chart

all_films_chart.save('visualizations/definitive_films.html')

# %%
definitive_snl_chart = alt.Chart(definitive_snl).mark_circle(size=60).encode(
  # Year on the X axis
    x=alt.X('year_start:Q', axis=alt.Axis(format='c', title='Year (Start)'),scale=alt.Scale(domain=(1990, 2022))),
    
    # Number of objects on the Y axis
    y=alt.Y('movie_coefficient:Q', title='SNL Coefficient'),
    
    # Color according to the type
    color = alt.condition(alt.datum.movie_coefficient < 1, alt.value('red'), alt.value('blue')),
    
    # Details on hover
    tooltip=[alt.Tooltip('title:N', title='Title'), 
             alt.Tooltip('year_start:Q', title='Year (Start)'),
             alt.Tooltip('genres:N', title='Genre'),
             alt.Tooltip('medium:N', title='Medium'),
             alt.Tooltip('cast_count:Q', title='Cast Count'),
             alt.Tooltip('movie_coefficient:Q', title='Coefficient')]
).interactive()

definitive_snl_chart

definitive_snl_chart.save('visualizations/definitive_snl_chart.html')
